# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# %matplotlib inline

# %%
data = {
    "State/UT": [
        "Uttar Pradesh",
        "Maharashtra",
        "Bihar",
        "West Bengal",
        "Andhra Pradesh (2011 boundaries)",
        "Madhya Pradesh",
        "Tamil Nadu"
    ],
    "Population_2011": [
        199812341, 112374333, 104099452,
        91276115, 84580777, 72626809, 72147030
    ],
    "LiteracyRate_2011": [67.68, 82.34, 61.80, 76.26, 67.02, 69.32, 80.09]
}
df = pd.DataFrame(data)
print(df)
# Out:
#                            State/UT  Population_2011  LiteracyRate_2011
# 0                     Uttar Pradesh        199812341              67.68
# 1                       Maharashtra        112374333              82.34
# 2                             Bihar        104099452              61.80
# 3                       West Bengal         91276115              76.26
# 4  Andhra Pradesh (2011 boundaries)         84580777              67.02
# 5                    Madhya Pradesh         72626809              69.32
# 6                        Tamil Nadu         72147030              80.09

# %%
df["Estimated_Literate"] = (df["Population_2011"] * (df["LiteracyRate_2011"] / 100)).astype(int)
df["Estimated_NonLiterate"] = df["Population_2011"] - df["Estimated_Literate"]

# %%
target = 90
df["Gap_to_90_pct_points"] = (target - df["LiteracyRate_2011"]).clip(lower=0)
df["Priority_Score"] = (df["Gap_to_90_pct_points"] / 100) * df["Population_2011"]

# %%
print("\n Basic Info: ")
print(df.info())
print("\n Statistical Summary:")
print(df.describe())
# Out:
#  Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   State/UT               7 non-null      object
#  1   Population_2011        7 non-null      int64
#  2   LiteracyRate_2011      7 non-null      float64
#  3   Estimated_Literate     7 non-null      int64
#  4   Estimated_NonLiterate  7 non-null      int64
#  5   Gap_to_90_pct_points   7 non-null      float64
#  6   Priority_Score         7 non-null      float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 524.0+ bytes
# None
#
#  Statistical Summary:
#        Population_2011  LiteracyRate_2011  Estimated_Literate  \
# count     7.000000e+00           7.000000        7.000000e+00
# mean      1.052738e+08          72.072857        7.521659e+07
# std       4.430327e+07           7.584626        2.977002e+07
# min       7.214703e+07          61.800000        5.034490e+07
# 25%       7.860379e+07          67.350000        5.723430e+07
# 50%       9.127612e+07          69.320000        6.433346e+07
# 75%       1.082369e+08          78.175000        8.106810e+07
# max       1.998123e+08          82.340000        1.352330e+08
#
#        Estimated_NonLiterate  Gap_to_90_pct_points  Priority_Score
# count           7.000000e+00              7.000000    7.000000e+00
# mean            3.005725e+07             17.927143    1.952986e+07
# std             1.718564e+07              7.584626    1.333368e+07
# min             1.436447e+07              7.660000    7.149771e+06
# 25%             2.075713e+07             11.825000    1.057461e+07
# 50%             2.228191e+07             20.680000    1.501922e+07
# 75%             3.383037e+07             22.650000    2.439635e+07
# max             6.457935e+07             28.200000    4.459811e+07

# %%
plt.figure(figsize=(10,5))
df_sorted = df.sort_values("LiteracyRate_2011", ascending=False)
plt.bar(df_sorted["State/UT"], df_sorted["LiteracyRate_2011"], color='skyblue')
plt.axhline(90, linestyle='--', color='red', label='Target 90%')
plt.title("Literacy Rate (2011) by State")
plt.ylabel("Effective Literacy Rate (%)")
plt.xticks(rotation=25, ha="right")
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sizes = (df["Estimated_NonLiterate"] / 1_000_000) * 10
plt.scatter(df["LiteracyRate_2011"], df["Population_2011"]/1_000_000, s=sizes, alpha=0.6)
for i, row in df.iterrows():
    plt.annotate(row["State/UT"].split()[0],
                 (row["LiteracyRate_2011"], row["Population_2011"]/1_000_000),
                 fontsize=8)
plt.axvline(90, linestyle='--', color='red')
plt.xlabel("Literacy Rate (%)")
plt.ylabel("Population (Millions)")
plt.title("Population vs Literacy (Bubble = Non-Literate Population)")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
priority = df.sort_values("Priority_Score", ascending=False)
plt.bar(priority["State/UT"], priority["Priority_Score"]/1_000_000, color='orange')
plt.title("Priority to Reach 90% Literacy (Gap × Population)")
plt.ylabel("Priority (Millions of People)")
plt.xticks(rotation=25, ha="right")
plt.tight_layout()
plt.show()

# %%
fig = px.scatter(df, x="LiteracyRate_2011", y="Population_2011", size="Estimated_NonLiterate", color="State/UT", hover_name="State/UT",title="Interactive: Population vs Literacy Rate (Census 2011)",
    labels={"Population_2011": "Population (2011)", "LiteracyRate_2011": "Literacy Rate (%)"}
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="40726a24-0fca-47ba-ba70-2a7d140a85b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40726a24-0fca-47ba-ba70-2a7d140a85b1")) {                    Plotly.newPlot(                        "40726a24-0fca-47ba-ba70-2a7d140a85b1",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eState\u002fUT=Uttar Pradesh\u003cbr\u003eLiteracy Rate (%)=%{x}\u003cbr\u003ePopulation (2011)=%{y}\u003cbr\u003eEstimated_NonLiterate=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Uttar Pradesh"],"legendgroup":"Uttar Pradesh","marker":{"color":"#636efa","size":[64579349],"sizemode":"area","sizeref":161448.3725,"symbol":"circle"},"mode":"markers","name":"Uttar Pradesh","orientation":"v","showlegend":true,"x":[67.68],"xaxis":"x","y":[199812341],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eState\u002fUT=Maharashtra\u003cbr\u003eLiteracy Rate (%)=%{x}\u003cbr\u003ePopulation (2011)=%{y}\u003cbr\u003eEstimated_NonLiterate=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Maharashtra"],"legendgroup":"Maharashtra","marker":{"color":"#EF553B","size":[19845308],"sizemode":"area","sizeref":161448.3725,"symbol":"circle"},"mode":"markers","name":"Maharashtra","orientation":"v","showlegend":true,"x":[82.34],"xaxis":"x","y":[112374333],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eState\u002fUT=Bihar\u003cbr\u003eLiteracy Rate (%)=%{x}\u003cbr\u003ePopulation (2011)=%{y}\u003cbr\u003eEstimated_NonLiterate=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Bihar"],"legendgroup":"Bihar","marker":{"color":"#00cc96","size":[39765991],"sizemode":"area","sizeref":161448.3725,"symbol":"circle"},"mode":"markers","name":"Bihar","orientation":"v","showlegend":true,"x":[61.8],"xaxis":"x","y":[104099452],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eState\u002fUT=West Bengal\u003cbr\u003eLiteracy Rate (%)=%{x}\u003cbr\u003ePopulation (2011)=%{y}\u003cbr\u003eEstimated_NonLiterate=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["West Bengal"],"legendgroup":"West Bengal","marker":{"color":"#ab63fa","size":[21668950],"sizemode":"area","sizeref":161448.3725,"symbol":"circle"},"mode":"markers","name":"West Bengal","orientation":"v","showlegend":true,"x":[76.26],"xaxis":"x","y":[91276115],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eState\u002fUT=Andhra Pradesh (2011 boundaries)\u003cbr\u003eLiteracy Rate (%)=%{x}\u003cbr\u003ePopulation (2011)=%{y}\u003cbr\u003eEstimated_NonLiterate=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Andhra Pradesh (2011 boundaries)"],"legendgroup":"Andhra Pradesh (2011 boundaries)","marker":{"color":"#FFA15A","size":[27894741],"sizemode":"area","sizeref":161448.3725,"symbol":"circle"},"mode":"markers","name":"Andhra Pradesh (2011 boundaries)","orientation":"v","showlegend":true,"x":[67.02],"xaxis":"x","y":[84580777],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eState\u002fUT=Madhya Pradesh\u003cbr\u003eLiteracy Rate (%)=%{x}\u003cbr\u003ePopulation (2011)=%{y}\u003cbr\u003eEstimated_NonLiterate=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Madhya Pradesh"],"legendgroup":"Madhya Pradesh","marker":{"color":"#19d3f3","size":[22281906],"sizemode":"area","sizeref":161448.3725,"symbol":"circle"},"m ...

# %%
df.to_csv(r"/content/census2011_literacy_top7.csv", index=False)
print("Data saved ")
# Out:
# Data saved

# %%
print("\n Insights Summary:")
print("1. Uttar Pradesh and Bihar have the highest literacy gap and population.")
print("2. Tamil Nadu and Maharashtra are near 80–82%, showing good progress.")
print("3. Targeted programs in UP, Bihar, and Andhra Pradesh can yield maximum impact.")
# Out:
#  Insights Summary:
# 1. Uttar Pradesh and Bihar have the highest literacy gap and population.
# 2. Tamil Nadu and Maharashtra are near 80–82%, showing good progress.
# 3. Targeted programs in UP, Bihar, and Andhra Pradesh can yield maximum impact.
